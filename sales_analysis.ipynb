# %%
product_sales.plot(kind='pie', autopct='%1.1f%%', title='Revenue by Product')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
product_sales = df.groupby('Product')['Revenue'].sum()
print(product_sales)
# Out:
# Product
# Apple     75
# Banana    60
# Orange    60
# Name: Revenue, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("sales_data.csv")

print(df.head())
print("Shape:", df.shape)

df['Revenue'] = df['Quantity'] * df['Price']

region_sales = df.groupby('Region')['Revenue'].sum()
print(region_sales)

region_sales.plot(kind='bar', title='Revenue by Region', xlabel='Region', ylabel='Revenue', color='skyblue')
plt.tight_layout()
plt.show()
# Out:
#          Date Region Product  Quantity  Price
# 0  2024-01-01  North   Apple        10      5
# 1  2024-01-01  South  Banana        20      2
# 2  2024-01-02  North   Apple         5      5
# 3  2024-01-02   East  Orange        15      4
# 4  2024-01-03   West  Banana        10      2
# Shape: (5, 5)
# Region
# East     60
# North    75
# South    40
# West     20
# Name: Revenue, dtype: int64
